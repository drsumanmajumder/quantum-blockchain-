# %%
# Draw using ASCII art
print(qc.draw())

# Draw using the text drawer which doesn't require Matplotlib
qc.draw(output='text')
# Out:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├──────────────
#      └───┘┌─┴─┐     └╥┘     ┌─┐
# q_1: ─────┤ X ├──■───╫──────┤M├──────
#           └───┘┌─┴─┐ ║      └╥┘┌─┐
# q_2: ──────────┤ X ├─╫───■───╫─┤M├───
#                └───┘ ║ ┌─┴─┐ ║ └╥┘┌─┐
# q_3: ────────────────╫─┤ X ├─╫──╫─┤M├
#                      ║ └───┘ ║  ║ └╥┘
# c: 4/════════════════╩═══════╩══╩══╩═
#                      0       1  2  3
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├──────────────
#      └───┘┌─┴─┐     └╥┘     ┌─┐
# q_1: ─────┤ X ├──■───╫──────┤M├──────
#           └───┘┌─┴─┐ ║      └╥┘┌─┐
# q_2: ──────────┤ X ├─╫───■───╫─┤M├───
#                └───┘ ║ ┌─┴─┐ ║ └╥┘┌─┐
# q_3: ────────────────╫─┤ X ├─╫──╫─┤M├
#                      ║ └───┘ ║  ║ └╥┘
# c: 4/════════════════╩═══════╩══╩══╩═
#                      0       1  2  3

# %%
from qiskit import QuantumCircuit, execute, Aer

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    qc.measure(0,0)
    qc.measure(1,1)
    qc.measure(2,2)
    qc.measure(3,3)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)

    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# You can use ghz_circuit.draw('mpl') to visualize the circuit if you have matplotlib installed
# Draw using ASCII art
print(qc.draw())

# Draw using the text drawer which doesn't require Matplotlib
qc.draw(output='text')
# Out:
# {'1111': 506, '0000': 494}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-926f197a3164> in <module>
#      39 # You can use ghz_circuit.draw('mpl') to visualize the circuit if you have matplotlib installed
#      40 # Draw using ASCII art
# ---> 41 print(qc.draw())
#      42
#      43 # Draw using the text drawer which doesn't require Matplotlib
#
# NameError: name 'qc' is not defined

# %%
from qiskit import QuantumCircuit, execute, Aer

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    qc.measure(0, 0)
    qc.measure(1, 1)
    qc.measure(2, 2)
    qc.measure(3, 3)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Draw using ASCII art
print(ghz_circuit.draw())

# Draw using the text drawer which doesn't require Matplotlib
print(ghz_circuit.draw(output='text'))
# Out:
# {'0000': 497, '1111': 503}
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├──────────────
#      └───┘┌─┴─┐     └╥┘     ┌─┐
# q_1: ─────┤ X ├──■───╫──────┤M├──────
#           └───┘┌─┴─┐ ║      └╥┘┌─┐
# q_2: ──────────┤ X ├─╫───■───╫─┤M├───
#                └───┘ ║ ┌─┴─┐ ║ └╥┘┌─┐
# q_3: ────────────────╫─┤ X ├─╫──╫─┤M├
#                      ║ └───┘ ║  ║ └╥┘
# c: 4/════════════════╩═══════╩══╩══╩═
#                      0       1  2  3
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├──────────────
#      └───┘┌─┴─┐     └╥┘     ┌─┐
# q_1: ─────┤ X ├──■───╫──────┤M├──────
#           └───┘┌─┴─┐ ║      └╥┘┌─┐
# q_2: ──────────┤ X ├─╫───■───╫─┤M├───
#                └───┘ ║ ┌─┴─┐ ║ └╥┘┌─┐
# q_3: ────────────────╫─┤ X ├─╫──╫─┤M├
#                      ║ └───┘ ║  ║ └╥┘
# c: 4/════════════════╩═══════╩══╩══╩═
#                      0       1  2  3

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    qc.measure(0, 0)
    qc.measure(1, 1)
    qc.measure(2, 2)
    qc.measure(3, 3)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Draw the circuit using the 'mpl' backend with 'iqx' style
# This requires a functioning Matplotlib installation
try:
    ghz_circuit.draw('mpl', style='iqx')
except ImportError as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    print(ghz_circuit.draw())
# Out:
# {'0000': 510, '1111': 490}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Set the Matplotlib backend
plt.switch_backend('agg')

# Draw the circuit using the 'mpl' backend with 'iqx' style
try:
    # Draw the circuit
    figure = ghz_circuit.draw('mpl', style='iqx')
    
    # Show the plot
    plt.show()

    # Optionally save the figure to a file
    figure.savefig('ghz_circuit.png')
except Exception as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    ascii_fig = ghz_circuit.draw(output='text')
    print(ascii_fig)
# Out:
# {'1111': 472, '0000': 528}
# /home/suman/.local/lib/python3.6/site-packages/ipykernel_launcher.py:49: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.ignis.mitigation.measurement import (complete_meas_cal, 
                                                  CompleteMeasFitter)

# Assuming ghz_circuit is your quantum circuit creating the GHZ state

# Step 1: Measurement Error Mitigation
# Create measurement calibration circuits for 4 qubits
cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], 
                                               circlabel='measerrormitigationcal')
# Execute the calibration circuits
backend = Aer.get_backend('qasm_simulator')
cal_jobs = execute(cal_circuits, backend=backend, shots=1000)
cal_results = cal_jobs.result()

# Step 2: Fit the results
meas_fitter = CompleteMeasFitter(cal_results, state_labels)

# Step 3: Apply the calibration
mitigated_results = meas_fitter.filter.apply(result)

# Step 4: Calculate the fidelity
# The fidelity of the GHZ state can be calculated by examining the counts
counts = mitigated_results.get_counts(ghz_circuit)
# The fidelity is the probability of measuring the correct GHZ state
ghz_state = '0000'  # or '1111' for the GHZ state
fidelity = counts.get(ghz_state, 0) / sum(counts.values())

# Apply confidence interval calculation if needed...

print(f"Fidelity of GHZ state with QREM: {fidelity:.3f}")
# Out:
# /home/suman/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2a60b59d8b86> in <module>
#      18
#      19 # Step 3: Apply the calibration
# ---> 20 mitigated_results = meas_fitter.filter.apply(result)
#      21
#      22 # Step 4: Calculate the fidelity
#
# NameError: name 'result' is not defined

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit_experiments.framework import ParallelExperiment
from qiskit_experiments.library import StandardRB
from qiskit_experiments.library import StateTomography
from qiskit_experiments.library import QSTFitter

# Your GHZ circuit creation code here...

# Step 1: Execute the GHZ circuit on the quantum backend
backend = Aer.get_backend('qasm_simulator')
ghz_job = execute(ghz_circuit, backend=backend, shots=1000)
ghz_result = ghz_job.result()

# Use state tomography to get the actual state
qst_exp = StateTomography(ghz_circuit)
qst_data = qst_exp.run(backend).block_for_results()
# Extract the tomography data (this will also apply readout error mitigation)
tomo_fitter = QSTFitter(qst_data.data())

# Assuming you know the ideal state vector for your GHZ state
from qiskit.quantum_info import state_fidelity
ideal_state = [1/2**0.5, 0, 0, 0, 0, 0, 0, 1/2**0.5]  # For a 3-qubit GHZ
fidelity = state_fidelity(tomo_fitter.fit(), ideal_state)

print(f"Fidelity of GHZ state: {fidelity:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-e8bcd14ecefe> in <module>
#       1 from qiskit import QuantumCircuit, execute, Aer
# ----> 2 from qiskit_experiments.framework import ParallelExperiment
#       3 from qiskit_experiments.library import StandardRB
#       4 from qiskit_experiments.library import StateTomography
#       5 from qiskit_experiments.library import QSTFitter
#
# ModuleNotFoundError: No module named 'qiskit_experiments'

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity
from qiskit import IBMQ

# Your GHZ circuit creation code here...

# Load IBM Q account
IBMQ.load_account()

# Step 1: Execute the GHZ circuit on the quantum backend
provider = IBMQ.get_provider(hub='your_hub', group='your_group', project='your_project')
backend = provider.get_backend('your_backend')
ghz_job = execute(ghz_circuit, backend=backend, shots=8192)
ghz_result = ghz_job.result()

# Step 2: Perform measurement error mitigation
meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_jobs = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_results = cal_jobs.result()
meas_fitter = CompleteMeasFitter(cal_results, state_labels)
mitigated_result = meas_fitter.filter.apply(ghz_result)

# Calculate the fidelity
fidelity = state_fidelity(mitigated_result.get_statevector(ghz_circuit), ghz_circuit)

print(f"Fidelity of GHZ state: {fidelity:.3f}")
# Out:
# ---------------------------------------------------------------------------
# IBMQAccountCredentialsNotFound            Traceback (most recent call last)
# <ipython-input-10-0d0156e2efcd> in <module>
#       7
#       8 # Load IBM Q account
# ----> 9 IBMQ.load_account()
#      10
#      11 # Step 1: Execute the GHZ circuit on the quantum backend
#
# ~/.local/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqfactory.py in load_account(self)
#     166         if not credentials_list:
#     167             raise IBMQAccountCredentialsNotFound(
# --> 168                 'No IBM Quantum Experience credentials found.')
#     169
#     170         if len(credentials_list) > 1:
#
# IBMQAccountCredentialsNotFound: 'No IBM Quantum Experience credentials found.'

# %%
from qiskit import QuantumCircuit, execute, IBMQ
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity

# First, load your IBMQ account
IBMQ.load_account()

# Function to create a 4-qubit GHZ state
def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)  # Apply Hadamard gate to the first qubit
    for qubit in range(num_qubits - 1):
        qc.cx(qubit, qubit + 1)  # Apply CNOT gates to create entanglement
    qc.measure(range(num_qubits), range(num_qubits))  # Measure all qubits
    return qc

# Create the GHZ circuit
ghz_circuit = create_ghz_circuit()

# Use a provider from the open IBM Q systems
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

# Select a backend (here, we are using a simulator)
backend = provider.get_backend('ibmq_qasm_simulator')

# Execute the GHZ circuit on the selected backend
ghz_job = execute(ghz_circuit, backend=backend, shots=8192)
ghz_result = ghz_job.result()

# Perform measurement error mitigation
meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_jobs = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_results = cal_jobs.result()
meas_fitter = CompleteMeasFitter(cal_results, state_labels)
mitigated_results = meas_fitter.filter.apply(ghz_result)

# Calculate the fidelity
# For a simulator, we would compare the resulting statevector with the ideal state
fidelity = state_fidelity(mitigated_results.get_statevector(ghz_circuit), ghz_circuit)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ---------------------------------------------------------------------------
# IBMQAccountCredentialsNotFound            Traceback (most recent call last)
# <ipython-input-11-2754cf5ba714> in <module>
#       4
#       5 # First, load your IBMQ account
# ----> 6 IBMQ.load_account()
#       7
#       8 # Function to create a 4-qubit GHZ state
#
# ~/.local/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqfactory.py in load_account(self)
#     166         if not credentials_list:
#     167             raise IBMQAccountCredentialsNotFound(
# --> 168                 'No IBM Quantum Experience credentials found.')
#     169
#     170         if len(credentials_list) > 1:
#
# IBMQAccountCredentialsNotFound: 'No IBM Quantum Experience credentials found.'

# %%
from qiskit import IBMQ

# Replace 'YOUR_API_TOKEN_HERE' with your actual API token.
IBMQ.save_account('5d58790946d4ac04fdd816c57f487861ca287efb3b664900ae3b14cd8fe14cc00ffa1f1b7273871fab8d72e9a2d50dd5e960294f78b7475a76d107e28410886a', overwrite=True)

# %%
from qiskit import IBMQ

IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit import QuantumCircuit, execute, IBMQ
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity

# First, load your IBMQ account
IBMQ.load_account()

# Function to create a 4-qubit GHZ state
def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)  # Apply Hadamard gate to the first qubit
    for qubit in range(num_qubits - 1):
        qc.cx(qubit, qubit + 1)  # Apply CNOT gates to create entanglement
    qc.measure(range(num_qubits), range(num_qubits))  # Measure all qubits
    return qc

# Create the GHZ circuit
ghz_circuit = create_ghz_circuit()

# Use a provider from the open IBM Q systems
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

# Select a backend (here, we are using a simulator)
backend = provider.get_backend('ibmq_qasm_simulator')

# Execute the GHZ circuit on the selected backend
ghz_job = execute(ghz_circuit, backend=backend, shots=8192)
ghz_result = ghz_job.result()

# Perform measurement error mitigation
meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_jobs = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_results = cal_jobs.result()
meas_fitter = CompleteMeasFitter(cal_results, state_labels)
mitigated_results = meas_fitter.filter.apply(ghz_result)

# Calculate the fidelity
# For a simulator, we would compare the resulting statevector with the ideal state
fidelity = state_fidelity(mitigated_results.get_statevector(ghz_circuit), ghz_circuit)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ibmqfactory.load_account:WARNING:2024-04-27 13:41:52,305: Credentials are already in use. The existing account in the session will be replaced.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     324             return postprocess.format_statevector(
# --> 325                 self.data(experiment)["statevector"], decimals=decimals
#     326             )
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-14-2754cf5ba714> in <module>
#      37 # Calculate the fidelity
#      38 # For a simulator, we would compare the resulting statevector with the ideal state
# ...

# %%
from qiskit import QuantumCircuit, execute, IBMQ
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity

# Load your IBMQ account
provider = IBMQ.load_account()

# Function to create a 4-qubit GHZ state
def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)  # Apply Hadamard gate to the first qubit
    for qubit in range(1, num_qubits):
        qc.cx(0, qubit)  # Apply CNOT gates to entangle the qubits
    qc.measure(range(num_qubits), range(num_qubits))  # Measure all qubits
    return qc

# Create the GHZ circuit
ghz_circuit = create_ghz_circuit()

# Use a backend from IBMQ (change the backend name to a real device or another simulator as needed)
backend = provider.get_backend('ibmq_qasm_simulator')

# Execute the GHZ circuit
job = execute(ghz_circuit, backend=backend, shots=8192)
result = job.result()

# Perform measurement error mitigation
meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_job = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_result = cal_job.result()
meas_fitter = CompleteMeasFitter(cal_result, state_labels)
mitigated_result = meas_fitter.filter.apply(result)

# Calculate the fidelity
# For a simulator, we compare the resulting statevector (from simulation) with the ideal state
ideal_state = [1] + [0] * (2**4 - 2) + [1]  # Assuming a perfect GHZ state |0000> + |1111>
ideal_state = [x / 2**0.5 for x in ideal_state]
fidelity = state_fidelity(mitigated_result.get_statevector(ghz_circuit), ideal_state)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ibmqfactory.load_account:WARNING:2024-04-27 13:43:52,904: Credentials are already in use. The existing account in the session will be replaced.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     324             return postprocess.format_statevector(
# --> 325                 self.data(experiment)["statevector"], decimals=decimals
#     326             )
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-15-3013f75cd1c8> in <module>
#      36 ideal_state = [1] + [0] * (2**4 - 2) + [1]  # Assuming a perfect GHZ state |0000> + |1111>
#      37 ideal_state = [x / 2**0.5 for x in ideal_state]
# ...

# %%
from qiskit import IBMQ

# Check if an IBM Q account is already loaded, load if not
if not IBMQ.active_account():
    IBMQ.load_account()

# %%
from qiskit import QuantumCircuit, execute, IBMQ
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity

# Ensure only one instance of the account is loaded
if not IBMQ.active_account():
    IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for qubit in range(1, num_qubits):
        qc.cx(0, qubit)
    qc.measure(range(num_qubits), range(num_qubits))
    return qc

ghz_circuit = create_ghz_circuit()
backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(ghz_circuit, backend=backend, shots=8192)
result = job.result()

meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_job = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_result = cal_job.result()
meas_fitter = CompleteMeasFitter(cal_result, state_labels)
mitigated_result = meas_fitter.filter.apply(result)

ideal_state = [1] + [0] * (2**4 - 2) + [1]  # Adjust for the correct number of qubits
ideal_state = [x / 2**0.5 for x in ideal_state]
fidelity = state_fidelity(mitigated_result.get_statevector(ghz_circuit), ideal_state)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     324             return postprocess.format_statevector(
# --> 325                 self.data(experiment)["statevector"], decimals=decimals
#     326             )
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-17-bc65372f0bb5> in <module>
#      30 ideal_state = [1] + [0] * (2**4 - 2) + [1]  # Adjust for the correct number of qubits
#      31 ideal_state = [x / 2**0.5 for x in ideal_state]
# ---> 32 fidelity = state_fidelity(mitigated_result.get_statevector(ghz_circuit), ideal_state)
#      33
#      34 print(f'Fidelity of the GHZ state: {fidelity:.3f}')
#
# ...

# %%
from qiskit import QuantumCircuit, execute, IBMQ
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity

# Ensure only one instance of the account is loaded
if not IBMQ.active_account():
    IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for qubit in range(1, num_qubits):
        qc.cx(0, qubit)
    qc.measure(range(num_qubits), range(num_qubits))
    return qc

ghz_circuit = create_ghz_circuit()
backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(ghz_circuit, backend=backend, shots=8192)
result = job.result()

meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_job = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_result = cal_job.result()
meas_fitter = CompleteMeasFitter(cal_result, state_labels)
mitigated_result = meas_fitter.filter.apply(result)

ideal_state = [1] + [0] * (2**4 - 2) + [1]  # Adjust for the correct number of qubits
ideal_state = [x / 2**0.5 for x in ideal_state]
fidelity = state_fidelity(mitigated_result.get_statevector(ghz_circuit), ideal_state)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')

# %%
from qiskit import QuantumCircuit, execute, IBMQ
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.quantum_info import state_fidelity

# Ensure only one instance of the account is loaded
if not IBMQ.active_account():
    IBMQ.load_account()

provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for qubit in range(1, num_qubits):
        qc.cx(0, qubit)
    qc.measure(range(num_qubits), range(num_qubits))
    return qc

ghz_circuit = create_ghz_circuit()
backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(ghz_circuit, backend=backend, shots=8192)
result = job.result()

meas_cal_circuits, state_labels = complete_meas_cal(qr=ghz_circuit.qregs[0], circlabel='mcal')
cal_job = execute(meas_cal_circuits, backend=backend, shots=8192)
cal_result = cal_job.result()
meas_fitter = CompleteMeasFitter(cal_result, state_labels)
mitigated_result = meas_fitter.filter.apply(result)

ideal_state = [1] + [0] * (2**4 - 2) + [1]  # Adjust for the correct number of qubits
ideal_state = [x / 2**0.5 for x in ideal_state]
fidelity = state_fidelity(mitigated_result.get_statevector(ghz_circuit), ideal_state)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# /home/suman/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     324             return postprocess.format_statevector(
# --> 325                 self.data(experiment)["statevector"], decimals=decimals
#     326             )
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-1-bc65372f0bb5> in <module>
# ...

# %%
from qiskit import QuantumCircuit, execute, IBMQ, Aer
from qiskit_experiments.framework import BatchExperiment
from qiskit_experiments.library import StateTomography
from qiskit.quantum_info import state_fidelity, Statevector

# Load IBM Q account
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

# Function to create a GHZ state
def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for i in range(num_qubits - 1):
        qc.cx(i, i + 1)
    return qc

ghz_circuit = create_ghz_circuit()

# Select a backend
backend = Aer.get_backend('aer_simulator')

# Prepare state tomography experiment to reconstruct the quantum state
tomography_exp = StateTomography(ghz_circuit)
experiment = BatchExperiment([tomography_exp])

# Run the experiment
result = experiment.run(backend).block_for_results()

# Retrieve the state tomography data
tomo_result = result.component_experiment_data(0)

# Perform state tomography analysis
fitted_state = tomo_result.analysis_results("state").value

# Assuming the ideal GHZ state
ideal_state = Statevector.from_label('0' * 4) + Statevector.from_label('1' * 4)
ideal_state = ideal_state / ideal_state.norm()

# Calculate the fidelity
fidelity = state_fidelity(fitted_state, ideal_state, validate=False)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c73d3177f91e> in <module>
#       1 from qiskit import QuantumCircuit, execute, IBMQ, Aer
# ----> 2 from qiskit_experiments.framework import BatchExperiment
#       3 from qiskit_experiments.library import StateTomography
#       4 from qiskit.quantum_info import state_fidelity, Statevector
#       5
#
# ModuleNotFoundError: No module named 'qiskit_experiments'

# %%
try:
    import qiskit_experiments
    print("qiskit-experiments is successfully installed.")
except ImportError:
    print("qiskit-experiments is not installed.")
# Out:
# qiskit-experiments is not installed.

# %%
from qiskit import QuantumCircuit, execute, IBMQ, Aer
from qiskit_experiments.framework import BatchExperiment
from qiskit_experiments.library import StateTomography
from qiskit.quantum_info import state_fidelity, Statevector

# Load IBM Q account
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

# Function to create a GHZ state
def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for i in range(num_qubits - 1):
        qc.cx(i, i + 1)
    return qc

ghz_circuit = create_ghz_circuit()

# Select a backend
backend = Aer.get_backend('aer_simulator')

# Prepare state tomography experiment to reconstruct the quantum state
tomography_exp = StateTomography(ghz_circuit)
experiment = BatchExperiment([tomography_exp])

# Run the experiment
result = experiment.run(backend).block_for_results()

# Retrieve the state tomography data
tomo_result = result.component_experiment_data(0)

# Perform state tomography analysis
fitted_state = tomo_result.analysis_results("state").value

# Assuming the ideal GHZ state
ideal_state = Statevector.from_label('0' * 4) + Statevector.from_label('1' * 4)
ideal_state = ideal_state / ideal_state.norm()

# Calculate the fidelity
fidelity = state_fidelity(fitted_state, ideal_state, validate=False)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c73d3177f91e> in <module>
#       1 from qiskit import QuantumCircuit, execute, IBMQ, Aer
# ----> 2 from qiskit_experiments.framework import BatchExperiment
#       3 from qiskit_experiments.library import StateTomography
#       4 from qiskit.quantum_info import state_fidelity, Statevector
#       5
#
# ModuleNotFoundError: No module named 'qiskit_experiments'

# %%
#from qiskit import QuantumCircuit, execute, IBMQ, Aer
from qiskit import QuantumCircuit, IBMQ, Aer
from qiskit import execute
from qiskit_experiments.framework import BatchExperiment
from qiskit_experiments.library import StateTomography
from qiskit.quantum_info import state_fidelity, Statevector
from qiskit import QuantumCircuit, Aer
from qiskit.providers.ibmq import IBMQ
from qiskit.tools.monitor import job_monitor
from qiskit.providers.aer import AerSimulator

# Your other code remains the same


# Load IBM Q account
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

# Function to create a GHZ state
def create_ghz_circuit(num_qubits=4):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for i in range(num_qubits - 1):
        qc.cx(i, i + 1)
    return qc

ghz_circuit = create_ghz_circuit()

# Select a backend
backend = Aer.get_backend('aer_simulator')

# Prepare state tomography experiment to reconstruct the quantum state
tomography_exp = StateTomography(ghz_circuit)
experiment = BatchExperiment([tomography_exp])

# Run the experiment
result = experiment.run(backend).block_for_results()

# Retrieve the state tomography data
tomo_result = result.component_experiment_data(0)

# Perform state tomography analysis
fitted_state = tomo_result.analysis_results("state").value

# Assuming the ideal GHZ state
ideal_state = Statevector.from_label('0' * 4) + Statevector.from_label('1' * 4)
ideal_state = ideal_state / ideal_state.norm()

# Calculate the fidelity
fidelity = state_fidelity(fitted_state, ideal_state, validate=False)

print(f'Fidelity of the GHZ state: {fidelity:.3f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e8248bf23b5f> in <module>
#       2 from qiskit import QuantumCircuit, IBMQ, Aer
#       3 from qiskit import execute
# ----> 4 from qiskit_experiments.framework import BatchExperiment
#       5 from qiskit_experiments.library import StateTomography
#       6 from qiskit.quantum_info import state_fidelity, Statevector
#
# ModuleNotFoundError: No module named 'qiskit_experiments'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Set the Matplotlib backend
plt.switch_backend('agg')

# Draw the circuit using the 'mpl' backend with 'iqx' style
try:
    # Draw the circuit
    figure = ghz_circuit.draw('mpl', style='iqx')
    
    # Show the plot
    plt.show()

    # Optionally save the figure to a file
    figure.savefig('ghz_circuit.png')
except Exception as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    ascii_fig = ghz_circuit.draw(output='text')
    print(ascii_fig)
# Out:
# {'0000': 517, '1111': 483}
# /home/suman/.local/lib/python3.6/site-packages/ipykernel_launcher.py:49: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer
from qiskit.quantum_info import Statevector
from qiskit.ignis.verification import state_tomography_circuits, StateTomographyFitter

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Perform state tomography
tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
tomo_result = job.result()
fitter = StateTomographyFitter(tomo_result, tomo_circuits)
ghz_state = fitter.fit()

# Calculate the fidelity
ideal_state = Statevector.from_label('0000') + Statevector.from_label('1111')
ideal_state = ideal_state / ideal_state.norm()
fidelity = state_fidelity(ghz_state, ideal_state)
print(f"Fidelity of the GHZ state: {fidelity:.3f}")

# Set the Matplotlib backend
plt.switch_backend('agg')

# Draw the circuit using the 'mpl' backend with 'iqx' style
try:
    # Draw the circuit
    figure = ghz_circuit.draw('mpl', style='iqx')
    
    # Show the plot
    plt.show()

    # Optionally save the figure to a file
    figure.savefig('ghz_circuit.png')
except Exception as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    ascii_fig = ghz_circuit.draw(output='text')
    print(ascii_fig)
# Out:
# /home/suman/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#
# WARNING: circuit does not contain measured qubit: range(0, 4)
# WARNING: circuit does not contain prepared qubit: range(0, 4)
# {'0000': 506, '1111': 494}
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-3-39f6943a7d36> in <module>
#      41
#      42 # Perform state tomography
# ---> 43 tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
#      44 job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
#      45 tomo_result = job.result()
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer
from qiskit.quantum_info import Statevector
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Perform state tomography
tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
tomo_result = job.result()
fitter = StateTomographyFitter(tomo_result, tomo_circuits)
ghz_state = fitter.fit()

# Calculate the fidelity
ideal_state = Statevector.from_label('0000') + Statevector.from_label('1111')
ideal_state = ideal_state / ideal_state.norm()
fidelity = state_fidelity(ghz_state, ideal_state)
print(f"Fidelity of the GHZ state: {fidelity:.3f}")

# Set the Matplotlib backend
plt.switch_backend('agg')

# Draw the circuit using the 'mpl' backend with 'iqx' style
try:
    # Draw the circuit
    figure = ghz_circuit.draw('mpl', style='iqx')
    
    # Show the plot
    plt.show()

    # Optionally save the figure to a file
    figure.savefig('ghz_circuit.png')
except Exception as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    ascii_fig = ghz_circuit.draw(output='text')
    print(ascii_fig)
# Out:
# WARNING: circuit does not contain measured qubit: range(0, 4)
# WARNING: circuit does not contain prepared qubit: range(0, 4)
# {'1111': 480, '0000': 520}
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-4-a56769014b2a> in <module>
#      41
#      42 # Perform state tomography
# ---> 43 tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
#      44 job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
#      45 tomo_result = job.result()
#
# ~/.local/lib/python3.6/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py in state_tomography_circuits(circuit, measured_qubits, meas_labels, meas_basis)
#      77     return _tomography_circuits(circuit, measured_qubits, None,
#      78                                 meas_labels=meas_labels, meas_basis=meas_basis,
# ...

# %%
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer
from qiskit.quantum_info import Statevector
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Perform state tomography
tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
tomo_result = job.result()
fitter = StateTomographyFitter(tomo_result, tomo_circuits)
ghz_state = fitter.fit()

# Calculate the fidelity
ideal_state = Statevector.from_label('0000') + Statevector.from_label('1111')
ideal_state = ideal_state / ideal_state.norm()
fidelity = state_fidelity(ghz_state, ideal_state)
print(f"Fidelity of the GHZ state: {fidelity:.3f}")

# Set the Matplotlib backend
plt.switch_backend('agg')

# Draw the circuit using the 'mpl' backend with 'iqx' style
try:
    # Draw the circuit
    figure = ghz_circuit.draw('mpl', style='iqx')
    
    # Show the plot
    plt.show()

    # Optionally save the figure to a file
    figure.savefig('ghz_circuit.png')
except Exception as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    ascii_fig = ghz_circuit.draw(output='text')
    print(ascii_fig)
# Out:
# WARNING: circuit does not contain measured qubit: range(0, 4)
# WARNING: circuit does not contain prepared qubit: range(0, 4)
# {'1111': 499, '0000': 501}
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-5-9b405c425a2e> in <module>
#      40
#      41 # Perform state tomography
# ---> 42 tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
#      43 job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
#      44 tomo_result = job.result()
#
# ~/.local/lib/python3.6/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py in state_tomography_circuits(circuit, measured_qubits, meas_labels, meas_basis)
#      77     return _tomography_circuits(circuit, measured_qubits, None,
#      78                                 meas_labels=meas_labels, meas_basis=meas_basis,
# ...

# %%
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer
from qiskit.quantum_info import Statevector
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Perform state tomography
tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
tomo_result = job.result()
fitter = StateTomographyFitter(tomo_result, tomo_circuits)
ghz_state = fitter.fit()

# Calculate the fidelity
ideal_state = Statevector.from_label('0000') + Statevector.from_label('1111')
ideal_state = ideal_state / ideal_state.norm()
fidelity = state_fidelity(ghz_state, ideal_state)
print(f"Fidelity of the GHZ state: {fidelity:.3f}")

# Draw the circuit using the 'mpl' backend with 'iqx' style
try:
    # Draw the circuit
    figure = ghz_circuit.draw('mpl', style='iqx')
    
    # Show the plot
    plt.show()

    # Optionally save the figure to a file
    figure.savefig('ghz_circuit.png')
except Exception as e:
    print("An error occurred with drawing the circuit using Matplotlib: ", e)
    # Draw using ASCII art as a fallback
    ascii_fig = ghz_circuit.draw(output='text')
    print(ascii_fig)
# Out:
# WARNING: circuit does not contain measured qubit: range(0, 4)
# WARNING: circuit does not contain prepared qubit: range(0, 4)
# {'0000': 524, '1111': 476}
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-6-1440b20144aa> in <module>
#      40
#      41 # Perform state tomography
# ---> 42 tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
#      43 job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
#      44 tomo_result = job.result()
#
# ~/.local/lib/python3.6/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py in state_tomography_circuits(circuit, measured_qubits, meas_labels, meas_basis)
#      77     return _tomography_circuits(circuit, measured_qubits, None,
#      78                                 meas_labels=meas_labels, meas_basis=meas_basis,
# ...

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import circuit_drawer
from qiskit.quantum_info import Statevector
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter

def ghz_4qubit():
    """
    Create a GHZ (entangled 4-qubit system) quantum circuit and execute it.
    """
    # Create a Quantum Circuit with 4 qubits and 4 classical bits for measurement
    qc = QuantumCircuit(4, 4)
    
    # Apply a Hadamard gate on the first qubit
    qc.h(0)
    
    # Apply CNOT gates to entangle the qubits
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.cx(2, 3)
    
    # Measure the qubits into the classical bits
    for i in range(4):
        qc.measure(i, i)
    
    # Execute the circuit on the qasm simulator backend
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1000)
    result = job.result()
    
    # Print the measurement results
    counts = result.get_counts(qc)
    print(counts)
    
    # Return the executed circuit and the measurement results
    return qc, counts

# Call the function and get the circuit and results
ghz_circuit, measurement_results = ghz_4qubit()

# Perform state tomography
tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
tomo_result = job.result()
fitter = StateTomographyFitter(tomo_result, tomo_circuits)
ghz_state = fitter.fit()

# Calculate the fidelity
ideal_state = Statevector.from_label('0000') + Statevector.from_label('1111')
ideal_state = ideal_state / ideal_state.norm()
fidelity = state_fidelity(ghz_state, ideal_state)
print(f"Fidelity of the GHZ state: {fidelity:.3f}")

# Draw the circuit using the 'text' backend
print(ghz_circuit.draw(output='text'))
# Out:
# WARNING: circuit does not contain measured qubit: range(0, 4)
# WARNING: circuit does not contain prepared qubit: range(0, 4)
# {'1111': 476, '0000': 524}
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-7-99bfcb6482d7> in <module>
#      39
#      40 # Perform state tomography
# ---> 41 tomo_circuits = state_tomography_circuits(ghz_circuit, range(4))
#      42 job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
#      43 tomo_result = job.result()
#
# ~/.local/lib/python3.6/site-packages/qiskit/ignis/verification/tomography/basis/circuits.py in state_tomography_circuits(circuit, measured_qubits, meas_labels, meas_basis)
#      77     return _tomography_circuits(circuit, measured_qubits, None,
#      78                                 meas_labels=meas_labels, meas_basis=meas_basis,
# ...

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# Function to create a GHZ state quantum circuit
def ghz_circuit(num_qubits):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for i in range(num_qubits - 1):
        qc.cx(i, i+1)
    qc.measure(range(num_qubits), range(num_qubits))
    return qc

# Execute the circuit and get measurement results
def execute_circuit(circuit, shots=1024):
    backend = Aer.get_backend('qasm_simulator')
    job = execute(circuit, backend, shots=shots)
    result = job.result()
    counts = result.get_counts(circuit)
    return counts

# Calculate fidelity using state tomography
def calculate_fidelity(circuit, counts, num_qubits):
    measured_qubits = list(range(num_qubits))  # Measure all qubits
    tomo_circuits = state_tomography_circuits(circuit, measured_qubits)
    job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
    tomo_result = job.result()
    fitter = StateTomographyFitter(tomo_result, tomo_circuits)
    ghz_state = fitter.fit()
    ideal_state = Statevector.from_label('0'*num_qubits) + Statevector.from_label('1'*num_qubits)
    ideal_state /= ideal_state.norm()
    fidelity = state_fidelity(ghz_state, ideal_state)
    return fidelity

# Main function
def main():
    num_qubits = 27  # Choose the number of qubits for the GHZ state
    circuit = ghz_circuit(num_qubits)
    counts = execute_circuit(circuit)
    fidelity = calculate_fidelity(circuit, counts, num_qubits)
    print(f"Fidelity of the GHZ state with {num_qubits} qubits: {fidelity}")
    if fidelity >= 0.5:
        print("The fidelity surpasses the threshold of 0.5.")
    else:
        print("The fidelity does not surpass the threshold of 0.5.")

if __name__ == "__main__":
    main()

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram
from qiskit.ignis.verification.tomography import state_tomography_circuits, StateTomographyFitter
from qiskit.quantum_info import state_fidelity

# Function to create a GHZ state quantum circuit
def ghz_circuit(num_qubits):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for i in range(num_qubits - 1):
        qc.cx(i, i+1)
    qc.measure(range(num_qubits), range(num_qubits))
    return qc

# Execute the circuit and get measurement results
def execute_circuit(circuit, shots=1024):
    backend = Aer.get_backend('qasm_simulator')
    job = execute(circuit, backend, shots=shots)
    result = job.result()
    counts = result.get_counts(circuit)
    return counts

# Calculate fidelity using state tomography
def calculate_fidelity(circuit, counts, num_qubits):
    measured_qubits = list(range(num_qubits))  # Measure all qubits
    tomo_circuits = state_tomography_circuits(circuit, measured_qubits)
    job = execute(tomo_circuits, backend=Aer.get_backend('qasm_simulator'), shots=1000)
    tomo_result = job.result()
    fitter = StateTomographyFitter(tomo_result, tomo_circuits)
    ghz_state = fitter.fit()
    ideal_state = Statevector.from_label('0'*num_qubits) + Statevector.from_label('1'*num_qubits)
    ideal_state /= ideal_state.norm()
    fidelity = state_fidelity(ghz_state, ideal_state)
    return fidelity

# Main function
def main():
    num_qubits = 27  # Choose the number of qubits for the GHZ state
    circuit = ghz_circuit(num_qubits)
    counts = execute_circuit(circuit)
    fidelity = calculate_fidelity(circuit, counts, num_qubits)
    print(f"Fidelity of the GHZ state with {num_qubits} qubits: {fidelity}")
    if fidelity >= 0.5:
        print("The fidelity surpasses the threshold of 0.5.")
    else:
        print("The fidelity does not surpass the threshold of 0.5.")

if __name__ == "__main__":
    main()
# Out:
# /home/suman/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram
from qiskit.experiments.quantum_circuit_library import StateTomography

# Function to create a GHZ state quantum circuit
def ghz_circuit(num_qubits):
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(0)
    for i in range(num_qubits - 1):
        qc.cx(i, i+1)
    qc.measure(range(num_qubits), range(num_qubits))
    return qc

# Execute the circuit and get measurement results
def execute_circuit(circuit, shots=1024):
    backend = Aer.get_backend('qasm_simulator')
    job = execute(circuit, backend, shots=shots)
    result = job.result()
    counts = result.get_counts(circuit)
    return counts

# Calculate fidelity using state tomography
def calculate_fidelity(circuit, counts, num_qubits):
    tomo = StateTomography(circuit, range(num_qubits))
    job = execute(tomo, backend=Aer.get_backend('qasm_simulator'), shots=1000)
    tomo_result = job.result()
    ghz_state = tomo.fit()
    ideal_state = Statevector.from_label('0'*num_qubits) + Statevector.from_label('1'*num_qubits)
    ideal_state /= ideal_state.norm()
    fidelity = ghz_state.fidelity(ideal_state)
    return fidelity

# Main function
def main():
    num_qubits = 27  # Choose the number of qubits for the GHZ state
    circuit = ghz_circuit(num_qubits)
    counts = execute_circuit(circuit)
    fidelity = calculate_fidelity(circuit, counts, num_qubits)
    print(f"Fidelity of the GHZ state with {num_qubits} qubits: {fidelity}")
    if fidelity >= 0.5:
        print("The fidelity surpasses the threshold of 0.5.")
    else:
        print("The fidelity does not surpass the threshold of 0.5.")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6de0cc668391> in <module>
#       1 from qiskit import QuantumCircuit, execute, Aer
#       2 from qiskit.visualization import plot_histogram
# ----> 3 from qiskit.experiments.quantum_circuit_library import StateTomography
#       4
#       5 # Function to create a GHZ state quantum circuit
#
# ModuleNotFoundError: No module named 'qiskit.experiments'
